# %%
import numpy as np
a = np.arange(600).reshape(30,20)
y = np.random.randint(0,9,30)
w = np.arange(200).reshape(10,20)
#ind = np.random.choice(30,10)
#y_prec = w.dot(a.T)
#y_prec = np.argmax(y_prec,axis=0)
#print(y_prec.shape)
#print(y_prec)
#y_s = y[ind]
#a_s = a[ind]
#print(y_s.shape)
#print(a_s.shape)
#print(a_s)
#print(y_s)
z1 = w.dot(a.T)
lgk = -1*np.amax(z1,axis=0)
z2 = np.exp(z1+lgk)
#z2 = w.dot(a.T)
#ay1 = z1[y[0]]
#y3 = np.arange(y.shape[0])
#ay2 = z2[y,y3]
#print(z2.shape)
#print(ay1)
#print(ay1.shape)
#print(ay2)
#z_n = np.delete(z,9)
#z_ind = np.sign(np.maximum(0,(1+z_n - ay)))
#z_ind = z_ind.reshape((np.shape(z_ind)[0],1))
#xx = np.multiply(a[0],z_ind)
#yy = -1* np.sum(xx,axis=0) +1
#zz = np.insert(xx,9,yy,axis=0)
#loss1 = np.sum(np.maximum(0,(1+z1 - ay1)))
#loss2 = np.sum((np.maximum(0,(1+z2 - ay2))),axis=0)

#dd = np.sign(np.maximum(0,(1+z2 - ay2)))
#dds = np.sum(dd,axis=0)
#print(dds.shape)
#dd[y,y3] = -1*dds +1
#dd = dd.dot(a)
#print(loss)
#print((1+z_n - ay))
#print(dd.shape)
#print(dd)
#print(z_ind)
#print(yy)
#print(xx)
#print(zz)
print(z1)
print(lgk)
print(z1+lgk)
#print(z2)
#print(loss1)
#print(loss2)
#print(z_n)
#print(w[0])
#print(a[0].T)
# Out:
# [[   2470    6270   10070   13870   17670   21470   25270   29070   32870
#     36670   40470   44270   48070   51870   55670   59470   63270   67070
#     70870   74670   78470   82270   86070   89870   93670   97470  101270
#    105070  108870  112670]
#  [   6270   18070   29870   41670   53470   65270   77070   88870  100670
#    112470  124270  136070  147870  159670  171470  183270  195070  206870
#    218670  230470  242270  254070  265870  277670  289470  301270  313070
#    324870  336670  348470]
#  [  10070   29870   49670   69470   89270  109070  128870  148670  168470
#    188270  208070  227870  247670  267470  287270  307070  326870  346670
#    366470  386270  406070  425870  445670  465470  485270  505070  524870
#    544670  564470  584270]
#  [  13870   41670   69470   97270  125070  152870  180670  208470  236270
#    264070  291870  319670  347470  375270  403070  430870  458670  486470
#    514270  542070  569870  597670  625470  653270  681070  708870  736670
# ...

# %%
print(w)
print(a)

# %%
d = np.arange(9)
print(d)

# %%
d[5]
